# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.0000, high=90.0000, size=2000)
lngs = np.random.uniform(low=-180.0000, high=180.0000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
from citipy import citipy

cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Perform an API call with the OpenWeatherMap
import requests
# Import the API key
from config import weather_api_key

# Build basic URL + API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=eba3522468d0a8ca6a2240c33ed79c78"

# %%
# Retrieve the following information from the API call
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kruisfontein
# Processing Record 2 of Set 1 | cabo san lucas
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | bushtyno
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | lata
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | kirakira
# Processing Record 9 of Set 1 | akyab
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | saint-pierre
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | cervo
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | haapu
# City not found. Skipping...
# Processing Record 18 of Set 1 | san luis
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | the valley
# Processing Record 21 of Set 1 | bilma
# Processing Record 22 of Set 1 | esperance
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | matriz de camaragibe
# Processing Record 25 of Set 1 | vila franca do campo
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | rawson
# Processing Record 29 of Set 1 | arlit
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | itarema
# Processing Record 35 of Set 1 | tilichiki
# Processing Record 36 of Set 1 | kulhudhuffushi
# Processing Record 37 of Set 1 | zharkent
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | constitucion
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | bereda
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | russkaya polyana
# Processing Record 47 of Set 1 | pierre
# Processing Record 48 of Set 1 | sorland
# Processing Record 49 of Set 1 | pallisa
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | avera
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | maningrida
# Processing Record 8 of Set 2 | fortuna
# Processing Record 9 of Set 2 | gamboula
# Processing Record 10 of Set 2 | sitka
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | nizwa
# Processing Record 14 of Set 2 | san patricio
# Processing Record 15 of Set 2 | hofn
# Processing Record 16 of Set 2 | regina
# Processing Record 17 of Set 2 | amberley
# Processing Record 18 of Set 2 | arman
# Processing Record 19 of Set 2 | zhigansk
# Processing Record 20 of Set 2 | ekhabi
# Processing Record 21 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 2 | nanortalik
# Processing Record 23 of Set 2 | cairns
# Processing Record 24 of Set 2 | deputatskiy
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | codrington
# Processing Record 27 of Set 2 | ajdabiya
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | okha
# Processing Record 30 of Set 2 | turukhansk
# Processing Record 31 of Set 2 | clyde river
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | tieli
# Processing Record 34 of Set 2 | boddam
# Processing Record 35 of Set 2 | shimoda
# Processing Record 36 of Set 2 | jamame
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | tiradentes
# Processing Record 39 of Set 2 | hambantota
# Processing Record 40 of Set 2 | constantine
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | sao filipe
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | fairbanks
# Processing Record 45 of Set 2 | port-cartier
# Processing Record 46 of Set 2 | comodoro rivadavia
# Processing Record 47 of Set 2 | kahului
# Processing Record 48 of Set 2 | san lawrenz
# Processing Record 49 of Set 2 | albany
# Processing Record 50 of Set 2 | pevek
# Processing Record 1 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 3 | chicama
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | emba
# Processing Record 5 of Set 3 | guerrero negro
# Processing Record 6 of Set 3 | ercis
# Processing Record 7 of Set 3 | ostrovnoy
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | luderitz
# Processing Record 10 of Set 3 | lagoa
# Processing Record 11 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 3 | bela
# Processing Record 13 of Set 3 | jipijapa
# Processing Record 14 of Set 3 | perth
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | sierra vista
# Processing Record 17 of Set 3 | qasigiannguit
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | puerto ayora
# Processing Record 20 of Set 3 | henties bay
# Processing Record 21 of Set 3 | villamontes
# Processing Record 22 of Set 3 | vila velha
# Processing Record 23 of Set 3 | acarau
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | mahajanga
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | moron
# Processing Record 28 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 3 | marsa matruh
# Processing Record 30 of Set 3 | along
# Processing Record 31 of Set 3 | qui nhon
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 3 | amuntai
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 3 | ambulu
# Processing Record 37 of Set 3 | chuy
# Processing Record 38 of Set 3 | yumen
# Processing Record 39 of Set 3 | necochea
# Processing Record 40 of Set 3 | papetoai
# Processing Record 41 of Set 3 | oriximina
# Processing Record 42 of Set 3 | vardo
# Processing Record 43 of Set 3 | soyo
# Processing Record 44 of Set 3 | nantucket
# Processing Record 45 of Set 3 | chokurdakh
# Processing Record 46 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 3 | awjilah
# Processing Record 48 of Set 3 | tiksi
# Processing Record 49 of Set 3 | muroto
# Processing Record 50 of Set 3 | chapais
# Processing Record 1 of Set 4 | linxia
# Processing Record 2 of Set 4 | fort nelson
# Processing Record 3 of Set 4 | nusaybin
# Processing Record 4 of Set 4 | ler
# Processing Record 5 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 6 of Set 4 | caravelas
# Processing Record 7 of Set 4 | kedrovyy
# Processing Record 8 of Set 4 | marawi
# Processing Record 9 of Set 4 | carnarvon
# Processing Record 10 of Set 4 | waw
# Processing Record 11 of Set 4 | evensk
# Processing Record 12 of Set 4 | barrow
# Processing Record 13 of Set 4 | lingao
# Processing Record 14 of Set 4 | aswan
# Processing Record 15 of Set 4 | cidreira
# Processing Record 16 of Set 4 | cockburn town
# Processing Record 17 of Set 4 | inndyr
# Processing Record 18 of Set 4 | buala
# Processing Record 19 of Set 4 | lagoa vermelha
# Processing Record 20 of Set 4 | nikki
# Processing Record 21 of Set 4 | long beach
# Processing Record 22 of Set 4 | qaanaaq
# Processing Record 23 of Set 4 | scarborough
# Processing Record 24 of Set 4 | muros
# Processing Record 25 of Set 4 | vega de alatorre
# Processing Record 26 of Set 4 | saint austell
# Processing Record 27 of Set 4 | asyut
# Processing Record 28 of Set 4 | ahipara
# Processing Record 29 of Set 4 | new norfolk
# Processing Record 30 of Set 4 | pisco
# Processing Record 31 of Set 4 | bardiyah
# Processing Record 32 of Set 4 | taywarah
# Processing Record 33 of Set 4 | mweka
# Processing Record 34 of Set 4 | genhe
# Processing Record 35 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 4 | haines junction
# Processing Record 37 of Set 4 | lompoc
# Processing Record 38 of Set 4 | rio gallegos
# Processing Record 39 of Set 4 | broome
# Processing Record 40 of Set 4 | chernyshevskiy
# Processing Record 41 of Set 4 | bambous virieux
# Processing Record 42 of Set 4 | krasnovishersk
# Processing Record 43 of Set 4 | xiaoshi
# Processing Record 44 of Set 4 | williston
# Processing Record 45 of Set 4 | ishinomaki
# Processing Record 46 of Set 4 | cayenne
# Processing Record 47 of Set 4 | makat
# Processing Record 48 of Set 4 | arraial do cabo
# Processing Record 49 of Set 4 | roald
# Processing Record 50 of Set 4 | grindavik
# Processing Record 1 of Set 5 | sola
# Processing Record 2 of Set 5 | lasa
# Processing Record 3 of Set 5 | arroio grande
# Processing Record 4 of Set 5 | esfarayen
# Processing Record 5 of Set 5 | brownsville
# Processing Record 6 of Set 5 | lavrentiya
# Processing Record 7 of Set 5 | kabinda
# Processing Record 8 of Set 5 | north bend
# Processing Record 9 of Set 5 | vanavara
# Processing Record 10 of Set 5 | kodiak
# Processing Record 11 of Set 5 | khatanga
# Processing Record 12 of Set 5 | lebu
# Processing Record 13 of Set 5 | faya
# Processing Record 14 of Set 5 | lorengau
# Processing Record 15 of Set 5 | bonavista
# Processing Record 16 of Set 5 | arkhangelos
# City not found. Skipping...
# Processing Record 17 of Set 5 | mizdah
# Processing Record 18 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 5 | bathsheba
# Processing Record 20 of Set 5 | bousso
# Processing Record 21 of Set 5 | sisimiut
# Processing Record 22 of Set 5 | colares
# Processing Record 23 of Set 5 | leon
# Processing Record 24 of Set 5 | talnakh
# Processing Record 25 of Set 5 | mbuyapey
# Processing Record 26 of Set 5 | narowal
# Processing Record 27 of Set 5 | northport
# Processing Record 28 of Set 5 | torbay
# Processing Record 29 of Set 5 | aktash
# Processing Record 30 of Set 5 | los llanos de aridane
# Processing Record 31 of Set 5 | eureka
# Processing Record 32 of Set 5 | provideniya
# Processing Record 33 of Set 5 | dunedin
# Processing Record 34 of Set 5 | lufilufi
# Processing Record 35 of Set 5 | geraldton
# Processing Record 36 of Set 5 | ocampo
# Processing Record 37 of Set 5 | banmo
# City not found. Skipping...
# Processing Record 38 of Set 5 | karratha
# Processing Record 39 of Set 5 | tirumullaivasal
# Processing Record 40 of Set 5 | mackay
# Processing Record 41 of Set 5 | rantepao
# Processing Record 42 of Set 5 | mayo
# Processing Record 43 of Set 5 | pocatello
# Processing Record 44 of Set 5 | havelock
# Processing Record 45 of Set 5 | rosarito
# Processing Record 46 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 5 | farafangana
# Processing Record 48 of Set 5 | viedma
# Processing Record 49 of Set 5 | bermeo
# Processing Record 50 of Set 5 | tondano
# Processing Record 1 of Set 6 | puerto escondido
# Processing Record 2 of Set 6 | ilebo
# Processing Record 3 of Set 6 | moose factory
# Processing Record 4 of Set 6 | narsaq
# Processing Record 5 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 6 | iberia
# Processing Record 7 of Set 6 | langsa
# Processing Record 8 of Set 6 | varzelandia
# Processing Record 9 of Set 6 | margate
# Processing Record 10 of Set 6 | syracuse
# Processing Record 11 of Set 6 | krasnoselkup
# Processing Record 12 of Set 6 | dourbali
# Processing Record 13 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 6 | san jose
# Processing Record 15 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 6 | mujiayingzi
# Processing Record 17 of Set 6 | derzhavinsk
# Processing Record 18 of Set 6 | norwich
# Processing Record 19 of Set 6 | weligama
# Processing Record 20 of Set 6 | san quintin
# Processing Record 21 of Set 6 | yulara
# Processing Record 22 of Set 6 | sobolevo
# Processing Record 23 of Set 6 | xuchang
# Processing Record 24 of Set 6 | partenit
# Processing Record 25 of Set 6 | santa lucia
# Processing Record 26 of Set 6 | asau
# Processing Record 27 of Set 6 | bengkulu
# Processing Record 28 of Set 6 | mount isa
# Processing Record 29 of Set 6 | pontianak
# Processing Record 30 of Set 6 | kovdor
# Processing Record 31 of Set 6 | port-gentil
# Processing Record 32 of Set 6 | victoria
# Processing Record 33 of Set 6 | neryungri
# Processing Record 34 of Set 6 | vostok
# Processing Record 35 of Set 6 | ngunguru
# Processing Record 36 of Set 6 | katherine
# Processing Record 37 of Set 6 | dabeiba
# Processing Record 38 of Set 6 | saldanha
# Processing Record 39 of Set 6 | friesach
# Processing Record 40 of Set 6 | great yarmouth
# Processing Record 41 of Set 6 | neiafu
# Processing Record 42 of Set 6 | kearney
# Processing Record 43 of Set 6 | mehamn
# Processing Record 44 of Set 6 | leningradskiy
# Processing Record 45 of Set 6 | half moon bay
# Processing Record 46 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 6 | port hardy
# Processing Record 48 of Set 6 | port elizabeth
# Processing Record 49 of Set 6 | namibe
# Processing Record 50 of Set 6 | millinocket
# Processing Record 1 of Set 7 | hasaki
# Processing Record 2 of Set 7 | vao
# Processing Record 3 of Set 7 | wattegama
# Processing Record 4 of Set 7 | lagunillas
# Processing Record 5 of Set 7 | port blair
# Processing Record 6 of Set 7 | buchmany
# Processing Record 7 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 7 | nikolskoye
# Processing Record 9 of Set 7 | atuona
# Processing Record 10 of Set 7 | mvuma
# Processing Record 11 of Set 7 | jiaocheng
# Processing Record 12 of Set 7 | yaan
# Processing Record 13 of Set 7 | ola
# Processing Record 14 of Set 7 | taunggyi
# Processing Record 15 of Set 7 | alexandria
# Processing Record 16 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 17 of Set 7 | huarmey
# Processing Record 18 of Set 7 | san rafael
# Processing Record 19 of Set 7 | canutama
# Processing Record 20 of Set 7 | zemio
# Processing Record 21 of Set 7 | boa vista
# Processing Record 22 of Set 7 | piacabucu
# Processing Record 23 of Set 7 | bonthe
# Processing Record 24 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 7 | wadena
# Processing Record 26 of Set 7 | mulege
# Processing Record 27 of Set 7 | manado
# Processing Record 28 of Set 7 | okhotsk
# Processing Record 29 of Set 7 | san julian
# Processing Record 30 of Set 7 | acapulco
# Processing Record 31 of Set 7 | solnechnyy
# Processing Record 32 of Set 7 | micco
# Processing Record 33 of Set 7 | ciechanow
# Processing Record 34 of Set 7 | pangnirtung
# Processing Record 35 of Set 7 | yanggu
# Processing Record 36 of Set 7 | bafra
# Processing Record 37 of Set 7 | zhangjiakou
# Processing Record 38 of Set 7 | kabalo
# Processing Record 39 of Set 7 | yatou
# Processing Record 40 of Set 7 | vyshneve
# Processing Record 41 of Set 7 | cravo norte
# Processing Record 42 of Set 7 | yeppoon
# Processing Record 43 of Set 7 | thompson
# Processing Record 44 of Set 7 | kargasok
# Processing Record 45 of Set 7 | baykit
# Processing Record 46 of Set 7 | bahia honda
# Processing Record 47 of Set 7 | sulangan
# Processing Record 48 of Set 7 | vung tau
# Processing Record 49 of Set 7 | iquitos
# Processing Record 50 of Set 7 | istanbul
# Processing Record 1 of Set 8 | troitsko-pechorsk
# Processing Record 2 of Set 8 | airai
# Processing Record 3 of Set 8 | sao joao da barra
# Processing Record 4 of Set 8 | katsuura
# Processing Record 5 of Set 8 | orlik
# Processing Record 6 of Set 8 | zheleznodorozhnyy
# Processing Record 7 of Set 8 | bisira
# Processing Record 8 of Set 8 | nuevo progreso
# Processing Record 9 of Set 8 | tateyama
# Processing Record 10 of Set 8 | angoche
# Processing Record 11 of Set 8 | tahe
# Processing Record 12 of Set 8 | tura
# Processing Record 13 of Set 8 | jacksonville
# Processing Record 14 of Set 8 | gao
# Processing Record 15 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 16 of Set 8 | portland
# Processing Record 17 of Set 8 | lima
# Processing Record 18 of Set 8 | praia da vitoria
# Processing Record 19 of Set 8 | burnie
# Processing Record 20 of Set 8 | tres arroyos
# Processing Record 21 of Set 8 | rio grande
# Processing Record 22 of Set 8 | serebryansk
# Processing Record 23 of Set 8 | copiapo
# Processing Record 24 of Set 8 | san cosme y damian
# Processing Record 25 of Set 8 | agadir
# Processing Record 26 of Set 8 | teahupoo
# Processing Record 27 of Set 8 | isangel
# Processing Record 28 of Set 8 | timra
# Processing Record 29 of Set 8 | stephenville
# Processing Record 30 of Set 8 | faisalabad
# Processing Record 31 of Set 8 | vastseliina
# Processing Record 32 of Set 8 | lascahobas
# Processing Record 33 of Set 8 | kailua
# Processing Record 34 of Set 8 | alofi
# Processing Record 35 of Set 8 | truro
# Processing Record 36 of Set 8 | ko samui
# Processing Record 37 of Set 8 | chunskiy
# Processing Record 38 of Set 8 | teya
# Processing Record 39 of Set 8 | santa vitoria do palmar
# Processing Record 40 of Set 8 | miles city
# Processing Record 41 of Set 8 | medea
# Processing Record 42 of Set 8 | grand forks
# Processing Record 43 of Set 8 | hovd
# Processing Record 44 of Set 8 | bambanglipuro
# Processing Record 45 of Set 8 | touros
# Processing Record 46 of Set 8 | hami
# Processing Record 47 of Set 8 | nalut
# Processing Record 48 of Set 8 | flin flon
# Processing Record 49 of Set 8 | meulaboh
# Processing Record 50 of Set 8 | madingou
# Processing Record 1 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 9 | anchorage
# Processing Record 3 of Set 9 | beysehir
# Processing Record 4 of Set 9 | zaliztsi
# Processing Record 5 of Set 9 | mawlaik
# Processing Record 6 of Set 9 | adre
# Processing Record 7 of Set 9 | shasta lake
# Processing Record 8 of Set 9 | chara
# Processing Record 9 of Set 9 | korla
# Processing Record 10 of Set 9 | ucluelet
# Processing Record 11 of Set 9 | bandarbeyla
# Processing Record 12 of Set 9 | mercedes
# Processing Record 13 of Set 9 | darlowo
# Processing Record 14 of Set 9 | limbuhan
# Processing Record 15 of Set 9 | faanui
# Processing Record 16 of Set 9 | dali
# Processing Record 17 of Set 9 | laguna
# Processing Record 18 of Set 9 | kon tum
# Processing Record 19 of Set 9 | bari
# Processing Record 20 of Set 9 | coquimbo
# Processing Record 21 of Set 9 | kavaratti
# Processing Record 22 of Set 9 | turayf
# Processing Record 23 of Set 9 | padang
# Processing Record 24 of Set 9 | beringovskiy
# Processing Record 25 of Set 9 | kloulklubed
# Processing Record 26 of Set 9 | imbituba
# Processing Record 27 of Set 9 | mahebourg
# Processing Record 28 of Set 9 | tessalit
# Processing Record 29 of Set 9 | porto novo
# Processing Record 30 of Set 9 | kangaatsiaq
# Processing Record 31 of Set 9 | prince rupert
# Processing Record 32 of Set 9 | bandrele
# Processing Record 33 of Set 9 | severnyy
# Processing Record 34 of Set 9 | nanakuli
# Processing Record 35 of Set 9 | zigong
# Processing Record 36 of Set 9 | hort
# Processing Record 37 of Set 9 | koumac
# Processing Record 38 of Set 9 | gizo
# Processing Record 39 of Set 9 | koratla
# Processing Record 40 of Set 9 | alta floresta
# Processing Record 41 of Set 9 | la asuncion
# Processing Record 42 of Set 9 | saint george
# Processing Record 43 of Set 9 | beloha
# Processing Record 44 of Set 9 | kofele
# Processing Record 45 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 9 | taltal
# Processing Record 47 of Set 9 | yangliuqing
# Processing Record 48 of Set 9 | joaima
# Processing Record 49 of Set 9 | camocim
# Processing Record 50 of Set 9 | tarakan
# Processing Record 1 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 10 | chumikan
# Processing Record 3 of Set 10 | oranjemund
# Processing Record 4 of Set 10 | letpadan
# Processing Record 5 of Set 10 | kuhdasht
# Processing Record 6 of Set 10 | imeni poliny osipenko
# Processing Record 7 of Set 10 | souillac
# Processing Record 8 of Set 10 | lichuan
# Processing Record 9 of Set 10 | ilulissat
# Processing Record 10 of Set 10 | misratah
# Processing Record 11 of Set 10 | phan thiet
# Processing Record 12 of Set 10 | san policarpo
# Processing Record 13 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 10 | sychevka
# Processing Record 15 of Set 10 | mbanza-ngungu
# Processing Record 16 of Set 10 | santa maria
# Processing Record 17 of Set 10 | berlevag
# Processing Record 18 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 19 of Set 10 | muzhi
# Processing Record 20 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 10 | san cristobal
# Processing Record 22 of Set 10 | richards bay
# Processing Record 23 of Set 10 | zyryanka
# Processing Record 24 of Set 10 | nisia floresta
# Processing Record 25 of Set 10 | salto
# Processing Record 26 of Set 10 | svetlaya
# Processing Record 27 of Set 10 | ewa beach
# Processing Record 28 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 10 | cap malheureux
# Processing Record 30 of Set 10 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 31 of Set 10 | enniscorthy
# Processing Record 32 of Set 10 | nome
# Processing Record 33 of Set 10 | baturaja
# Processing Record 34 of Set 10 | natagaima
# Processing Record 35 of Set 10 | praia
# Processing Record 36 of Set 10 | simpang
# Processing Record 37 of Set 10 | ergani
# Processing Record 38 of Set 10 | severobaykalsk
# Processing Record 39 of Set 10 | znamenka
# Processing Record 40 of Set 10 | salinas
# Processing Record 41 of Set 10 | husavik
# Processing Record 42 of Set 10 | badnawar
# Processing Record 43 of Set 10 | bay roberts
# Processing Record 44 of Set 10 | eden
# Processing Record 45 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 10 | mahon
# Processing Record 47 of Set 10 | maslovare
# Processing Record 48 of Set 10 | kabanjahe
# Processing Record 49 of Set 10 | gallup
# Processing Record 50 of Set 10 | gouyave
# Processing Record 1 of Set 11 | bolama
# Processing Record 2 of Set 11 | newbury
# Processing Record 3 of Set 11 | anklam
# Processing Record 4 of Set 11 | novoagansk
# Processing Record 5 of Set 11 | lalmohan
# Processing Record 6 of Set 11 | santa marinella
# Processing Record 7 of Set 11 | belaya gora
# Processing Record 8 of Set 11 | aksu
# Processing Record 9 of Set 11 | isiro
# Processing Record 10 of Set 11 | ixtapa
# Processing Record 11 of Set 11 | prado
# Processing Record 12 of Set 11 | tiarei
# Processing Record 13 of Set 11 | penapolis
# Processing Record 14 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 15 of Set 11 | berga
# Processing Record 16 of Set 11 | panama city
# Processing Record 17 of Set 11 | grudziadz
# Processing Record 18 of Set 11 | udachnyy
# Processing Record 19 of Set 11 | nyakabindi
# Processing Record 20 of Set 11 | san juan del rio
# Processing Record 21 of Set 11 | kollam
# Processing Record 22 of Set 11 | harlingen
# Processing Record 23 of Set 11 | manzil jamil
# City not found. Skipping...
# Processing Record 24 of Set 11 | kavieng
# Processing Record 25 of Set 11 | visnes
# Processing Record 26 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 27 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 11 | ossora
# Processing Record 29 of Set 11 | santa eulalia
# Processing Record 30 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 11 | suzu
# City not found. Skipping...
# Processing Record 32 of Set 11 | sambava
# Processing Record 33 of Set 11 | maniitsoq
# Processing Record 34 of Set 11 | fare
# Processing Record 35 of Set 11 | mount gambier
# Processing Record 36 of Set 11 | roebourne
# Processing Record 37 of Set 11 | marzuq
# Processing Record 38 of Set 11 | ust-kuyga
# Processing Record 39 of Set 11 | yuli
# Processing Record 40 of Set 11 | tarnok
# Processing Record 41 of Set 11 | nemuro
# Processing Record 42 of Set 11 | salta
# Processing Record 43 of Set 11 | tezu
# Processing Record 44 of Set 11 | lukh
# Processing Record 45 of Set 11 | sturgeon bay
# Processing Record 46 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 47 of Set 11 | svetlyy
# Processing Record 48 of Set 11 | kimbe
# Processing Record 49 of Set 11 | orikum
# Processing Record 50 of Set 11 | monrovia
# Processing Record 1 of Set 12 | san carlos de bariloche
# Processing Record 2 of Set 12 | loqueb
# Processing Record 3 of Set 12 | morant bay
# Processing Record 4 of Set 12 | gillette
# Processing Record 5 of Set 12 | nikolayevsk-na-amure
# Processing Record 6 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 12 | buraydah
# Processing Record 8 of Set 12 | bundaberg
# Processing Record 9 of Set 12 | makung
# City not found. Skipping...
# Processing Record 10 of Set 12 | hamilton
# Processing Record 11 of Set 12 | mae sot
# Processing Record 12 of Set 12 | buenos aires
# Processing Record 13 of Set 12 | tabuk
# Processing Record 14 of Set 12 | wanning
# Processing Record 15 of Set 12 | alice springs
# Processing Record 16 of Set 12 | mufumbwe
# Processing Record 17 of Set 12 | preobrazheniye
# Processing Record 18 of Set 12 | elat
# Processing Record 19 of Set 12 | novy bydzov
# Processing Record 20 of Set 12 | gamboma
# Processing Record 21 of Set 12 | roberval
# Processing Record 22 of Set 12 | castro verde
# Processing Record 23 of Set 12 | kuybyshevo
# Processing Record 24 of Set 12 | harper
# Processing Record 25 of Set 12 | sarangpur
# Processing Record 26 of Set 12 | sechelt
# Processing Record 27 of Set 12 | tatishchevo
# Processing Record 28 of Set 12 | brandon
# Processing Record 29 of Set 12 | samarai
# Processing Record 30 of Set 12 | independence
# Processing Record 31 of Set 12 | roma
# Processing Record 32 of Set 12 | riohacha
# Processing Record 33 of Set 12 | mhango
# Processing Record 34 of Set 12 | quiruvilca
# Processing Record 35 of Set 12 | venlo
# Processing Record 36 of Set 12 | lithgow
# Processing Record 37 of Set 12 | sinnamary
# Processing Record 38 of Set 12 | gobabis
# Processing Record 39 of Set 12 | inhambane
# Processing Record 40 of Set 12 | culaman
# Processing Record 41 of Set 12 | vestmannaeyjar
# Processing Record 42 of Set 12 | flinders
# Processing Record 43 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 44 of Set 12 | guipavas
# Processing Record 45 of Set 12 | umm kaddadah
# Processing Record 46 of Set 12 | kishtwar
# Processing Record 47 of Set 12 | houma
# Processing Record 48 of Set 12 | gushikawa
# Processing Record 49 of Set 12 | trinidad
# Processing Record 50 of Set 12 | zaysan
# Processing Record 1 of Set 13 | qaqortoq
# Processing Record 2 of Set 13 | pilar
# Processing Record 3 of Set 13 | kroya
# Processing Record 4 of Set 13 | lahij
# Processing Record 5 of Set 13 | tuatapere
# Processing Record 6 of Set 13 | shenjiamen
# Processing Record 7 of Set 13 | iralaya
# Processing Record 8 of Set 13 | forio
# Processing Record 9 of Set 13 | eyl
# Processing Record 10 of Set 13 | namatanai
# Processing Record 11 of Set 13 | loa janan
# Processing Record 12 of Set 13 | almeirim
# Processing Record 13 of Set 13 | saint-louis
# Processing Record 14 of Set 13 | jaisalmer
# Processing Record 15 of Set 13 | lao cai
# Processing Record 16 of Set 13 | gornozavodsk
# Processing Record 17 of Set 13 | ouadda
# Processing Record 18 of Set 13 | xuanhua
# Processing Record 19 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 13 | mezhdurechenskiy
# Processing Record 21 of Set 13 | navoi
# Processing Record 22 of Set 13 | ayagoz
# Processing Record 23 of Set 13 | healesville
# Processing Record 24 of Set 13 | whitianga
# Processing Record 25 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 13 | ust-maya
# Processing Record 27 of Set 13 | toluviejo
# Processing Record 28 of Set 13 | jiangyou
# Processing Record 29 of Set 13 | damghan
# Processing Record 30 of Set 13 | quixere
# Processing Record 31 of Set 13 | muli
# Processing Record 32 of Set 13 | dongning
# Processing Record 33 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 13 | rapid valley
# Processing Record 35 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 36 of Set 13 | pryazha
# Processing Record 37 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 13 | itoman
# Processing Record 39 of Set 13 | sfantu gheorghe
# Processing Record 40 of Set 13 | morondava
# Processing Record 41 of Set 13 | mangrol
# Processing Record 42 of Set 13 | lazaro cardenas
# Processing Record 43 of Set 13 | yubari
# Processing Record 44 of Set 13 | northam
# Processing Record 45 of Set 13 | wakkanai
# Processing Record 46 of Set 13 | marsh harbour
# Processing Record 47 of Set 13 | garmsar
# Processing Record 48 of Set 13 | wadi musa
# Processing Record 49 of Set 13 | dungarvan
# Processing Record 50 of Set 13 | morgan city
# Processing Record 1 of Set 14 | slyudyanka
# Processing Record 2 of Set 14 | saint anthony
# Processing Record 3 of Set 14 | alingsas
# Processing Record 4 of Set 14 | ulaanbaatar
# Processing Record 5 of Set 14 | pemangkat
# Processing Record 6 of Set 14 | abapo
# Processing Record 7 of Set 14 | marathon
# Processing Record 8 of Set 14 | sonder bjert
# Processing Record 9 of Set 14 | yuancheng
# Processing Record 10 of Set 14 | chihuahua
# Processing Record 11 of Set 14 | axim
# Processing Record 12 of Set 14 | quatre cocos
# Processing Record 13 of Set 14 | huron
# Processing Record 14 of Set 14 | marilia
# Processing Record 15 of Set 14 | bar harbor
# Processing Record 16 of Set 14 | le port
# Processing Record 17 of Set 14 | khuzhir
# Processing Record 18 of Set 14 | port hedland
# Processing Record 19 of Set 14 | benghazi
# Processing Record 20 of Set 14 | hihya
# Processing Record 21 of Set 14 | olinda
# Processing Record 22 of Set 14 | el dorado
# Processing Record 23 of Set 14 | barranca
# Processing Record 24 of Set 14 | pravia
# Processing Record 25 of Set 14 | nelson
# Processing Record 26 of Set 14 | bulolo
# Processing Record 27 of Set 14 | barentu
# Processing Record 28 of Set 14 | kortkeros
# Processing Record 29 of Set 14 | maiduguri
# Processing Record 30 of Set 14 | nicoya
# Processing Record 31 of Set 14 | zacualtipan
# Processing Record 32 of Set 14 | ancud
# Processing Record 33 of Set 14 | anadyr
# Processing Record 34 of Set 14 | tamandare
# Processing Record 35 of Set 14 | batagay-alyta
# Processing Record 36 of Set 14 | thunder bay
# Processing Record 37 of Set 14 | nanga eboko
# Processing Record 38 of Set 14 | blackfoot
# Processing Record 39 of Set 14 | nicolas bravo
# Processing Record 40 of Set 14 | matola
# Processing Record 41 of Set 14 | sur
# Processing Record 42 of Set 14 | praya
# Processing Record 43 of Set 14 | nouadhibou
# Processing Record 44 of Set 14 | komsomolskiy
# Processing Record 45 of Set 14 | astaneh-ye ashrafiyeh
# Processing Record 46 of Set 14 | sioux lookout
# Processing Record 47 of Set 14 | santiago
# Processing Record 48 of Set 14 | la rioja
# Processing Record 49 of Set 14 | ashland
# Processing Record 50 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 15 | whitehorse
# Processing Record 2 of Set 15 | tautira
# Processing Record 3 of Set 15 | umuahia
# Processing Record 4 of Set 15 | beyneu
# Processing Record 5 of Set 15 | verkhnyaya inta
# Processing Record 6 of Set 15 | norman wells
# Processing Record 7 of Set 15 | te anau
# Processing Record 8 of Set 15 | brae
# Processing Record 9 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 15 | valdosta
# Processing Record 11 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 12 of Set 15 | crowley
# Processing Record 13 of Set 15 | umm lajj
# Processing Record 14 of Set 15 | svirsk
# Processing Record 15 of Set 15 | kinablangan
# Processing Record 16 of Set 15 | gambo
# Processing Record 17 of Set 15 | maravatio
# Processing Record 18 of Set 15 | sol-iletsk
# Processing Record 19 of Set 15 | riviere-au-renard
# Processing Record 20 of Set 15 | tocopilla
# Processing Record 21 of Set 15 | bougouni
# Processing Record 22 of Set 15 | lannion
# Processing Record 23 of Set 15 | labuhan
# Processing Record 24 of Set 15 | abha
# Processing Record 25 of Set 15 | santa leopoldina
# Processing Record 26 of Set 15 | yarmouth
# Processing Record 27 of Set 15 | port augusta
# Processing Record 28 of Set 15 | sao joaquim da barra
# Processing Record 29 of Set 15 | salalah
# Processing Record 30 of Set 15 | hanson
# Processing Record 31 of Set 15 | laval
# Processing Record 32 of Set 15 | fort frances
# Processing Record 33 of Set 15 | tuy hoa
# Processing Record 34 of Set 15 | shache
# Processing Record 35 of Set 15 | byron bay
# Processing Record 36 of Set 15 | melita
# Processing Record 37 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 15 | hofu
# Processing Record 39 of Set 15 | srednekolymsk
# Processing Record 40 of Set 15 | mildura
# Processing Record 41 of Set 15 | middleton
# Processing Record 42 of Set 15 | tingrela
# City not found. Skipping...
# Processing Record 43 of Set 15 | baudh
# Processing Record 44 of Set 15 | indian head
# Processing Record 45 of Set 15 | abalak
# Processing Record 46 of Set 15 | poshekhonye
# Processing Record 47 of Set 15 | elko
# Processing Record 48 of Set 15 | kaitong
# Processing Record 49 of Set 15 | ginir
# Processing Record 50 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 1 of Set 16 | podlesnoye
# Processing Record 2 of Set 16 | myitkyina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kruisfontein      ZA -34.00   24.73     55.00        57          35
# 1  Cabo San Lucas      MX  22.89 -109.91     78.01        93         100
# 2     Yellowknife      CA  62.46 -114.35     46.99        93          90
# 3        Bushtyno      UA  48.05   23.49     87.80        45           0
# 4         Ushuaia      AR -54.80  -68.30     28.40        92          90
# 5            Lata      PT  40.16   -8.33     78.01        57           0
# 6         Mataura      NZ -46.19  168.86     45.00        72         100
# 7        Kirakira      SB -10.45  161.92     78.82        81          89
# 8           Akyab      MM  20.15   92.90     82.45        86          83
# 9           Bluff      NZ -46.60  168.33     45.00        72         100
#
#    Wind Speed Current Description
# 0       13.00    scattered clouds
# 1        1.01       moderate rain
# 2       17.22          light rain
# 3       11.41           clear sky
# 4        5.82                snow
# 5        8.01           clear sky
# 6       11.01     overcast clouds
# 7        7.72     overcast clouds
# 8        7.02       broken clouds
# 9       11.01          light rain

# %%
# Export the DataFrame as a CSV
output_data_file = "Weather_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
